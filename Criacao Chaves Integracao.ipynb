# %% [markdown]
# <p> Neste Notebook eu calculo a similaridade entre os nomes dos times ingleses presentes na Base FIFA e os times ingleses que disputam a Premier League presentes na Base BetExplorer. Algumas correções são feitas na base proveniente do BetExplorer para corrigir abreviações e nicknames, estas alterações foram feitas baseadas nos dados presentes em <a href="https://en.wikipedia.org/wiki/List_of_football_club_nicknames_in_the_United_Kingdom">List of football club nicknames in the United Kingdom</a>.</p>
#
# <p> Após a correção é feito o cálculo de similaridade de Jaccard e uma nova validação manual foi realizada para casos onde a similaridade calculada foi menor que 50%.</p>
#
# <p> As bases são então atualizadas com o ID de cada time.</p>

# %%
import pandas as pd
import numpy as np
import re
import unicodedata
from nltk import word_tokenize as wt
import matplotlib.pyplot as plt

# %% [markdown]
# <p>Após uma breve análise dos dados é possível perceber um padrão presente nos nomes dos times ingleses que é a presença frequente das palavras <b>United, City </b> e <b>Town</b>, o que pode gerar um grande impacto no cálculo de Jaccard visto que os nomes dos times possuem poucos palavras, variando entre 1 e 3 palavras. Visto isso foi realizada uma alteração no algoritmo onde casos onde a única similaridade encontrada era entre uma destas três palavras, a similaridade era então modificada para zero. A alteração foi feita para evitar missmatchs.</p>

# %%
def jaccard_similarity(label1, label2):
    label1 = wt(label1)
    label2 = wt(label2)
    if len(set(label1).intersection(set(label2)) - set(set(label1).intersection(set(label2))).intersection(set(['United','City','Town']))) == 0:
        return 0
    return len(set(label1).intersection(set(label2)))/len(set(label1).union(set(label2)))

def removerAcentosECaracteresEspeciais(colunas):
    retorno = []
    for palavra in colunas:
        # Unicode normalize transforma um caracter em seu equivalente em latin.
        nfkd = unicodedata.normalize('NFKD', palavra)
        palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

        # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
        retorno.append(re.sub('[^a-zA-Z0-9\\\]', ' ', palavraSemAcento))
    return retorno

def tratamentoNome(column):
    column = column.str.replace("FC","").str.replace("F C","")
    column = column.str.replace("Utd","United")
    return column

# %%
df_fifa = pd.read_csv('data/FIFA_CONSOLIDADO4.csv')
df_games = pd.read_csv('data/Games_Results.csv')
df_nicknames = pd.read_csv('data/England_NickNames.csv')

# %%
df_teams_id = df_fifa[df_fifa.Team_Country == 'England'][['Teams', 'Team_Country']].drop_duplicates().sort_values(by='Teams').reset_index(drop=True)
df_teams_id = df_teams_id.rename_axis('TeamID').reset_index()
df_fifa_england = df_fifa[df_fifa.Team_Country == 'England']
del df_fifa

# %% [markdown]
# <p>Através de validação manual com os dados presentes neste <a href="https://en.wikipedia.org/wiki/List_of_football_club_nicknames_in_the_United_Kingdom">link</a> é possível fazer a substituição abaixo.</p>

# %%
#Apenas para a Premier League
df_games = df_games[(df_games.Tournament == 'Premier League') & (df_games.Country == 'England')]
df_games.drop('Fase', axis=1,inplace=True)
df_games.loc[df_games.Home == 'QPR', 'Home'] = 'Queens Park Rangers'
df_games.loc[df_games.Away == 'QPR', 'Away'] = 'Queens Park Rangers'
df_games.loc[df_games.Home == 'Wolves', 'Home'] = 'Wolverhampton Wanderers'
df_games.loc[df_games.Away == 'Wolves', 'Away'] = 'Wolverhampton Wanderers'
df_games['Home_Team_ID'] = 0.0
df_games['Away_Team_ID'] = 0.0

# %%
home = df_games.Home.drop_duplicates()
away = df_games.Away.drop_duplicates()

# %%
df_fifa_teams = df_teams_id
df_fifa_teams['Perfect_Match'] = 0
df_integracao = pd.DataFrame({'Team':pd.concat([home,away]).drop_duplicates().reset_index(drop = True)})
df_integracao['Similaridade'] = 0.0
df_integracao['Match_Team'] = ''
df_integracao['TeamID'] = np.NaN
df_fifa_teams['Team_Sim'] = removerAcentosECaracteresEspeciais(df_fifa_teams.Teams)
df_integracao['Team_Sim'] = removerAcentosECaracteresEspeciais(df_integracao.Team)

# %%
# %%time
for id1, team1 in df_integracao.iterrows():
    for id2, team2 in df_fifa_teams.iterrows():
        if team2[-2] == 0:
            sim = jaccard_similarity(team1[-1],team2[-1])
            if sim > df_integracao.loc[id1,'Similaridade'].item() or (sim == df_integracao.loc[id1,'Similaridade'].item() and team2.str.contains(team1[-1])[-1]):
                df_integracao.loc[id1,'Similaridade'] = sim
                df_integracao.loc[id1,'Match_Team'] = df_fifa_teams.loc[id2,'Teams']
                df_integracao.loc[id1,'TeamID'] = df_fifa_teams.loc[id2,'TeamID']
                if sim == 1:
                    df_fifa_teams.loc[id2, 'Perfect_Match'] = 1
# Out:
# Wall time: 9.09 s

# %%
df_integracao.sort_values(by='Similaridade', ascending=False, inplace=True)
df_integracao
# Out:
#                        Team  Similaridade               Match_Team  TeamID  \
# 0                   Everton      1.000000                  Everton    39.0
# 13                Liverpool      1.000000                Liverpool    54.0
# 30               Portsmouth      1.000000               Portsmouth    75.0
# 25                   Fulham      1.000000                   Fulham    42.0
# 24          Manchester City      1.000000          Manchester City    57.0
# 1         Manchester United      1.000000        Manchester United    58.0
# 22               Sunderland      1.000000               Sunderland    90.0
# 20                  Watford      1.000000                  Watford    97.0
# 32           Crystal Palace      1.000000           Crystal Palace    33.0
# 16                  Chelsea      1.000000                  Chelsea    25.0
# 34                  Reading      1.000000                  Reading    78.0
# 36                Hull City      1.000000                Hull City    48.0
# 38                  Burnley      1.000000                  Burnley    18.0
# 10              Aston Villa      1.000000              Aston Villa     4.0
# 9                   Arsenal      1.000000                  Arsenal     3.0
# 8               Southampton      1.000000              Southampton    85.0
# 39                Blackpool      1.000000                Blackpool     9.0
# 40      Queens Park Rangers      1.000000      Queens Park Rangers    77.0
# 3             Middlesbrough      1.000000            Middlesbrough    60.0
# 43              Bournemouth      1.000000              Bournemouth    12.0
# 29  Wolverhampton Wanderers      1.000000  Wolverhampton Wanderers   101.0
# 19                 West Ham      0.666667          West Ham United    99.0
# 37                    Stoke      0.500000               Stoke City    89.0
# 28               Birmingham      0.500000          Birmingham City     7.0
# 33                    Wigan      0.500000           Wigan Athletic   100.0
# 31                  Norwich      0.500000             Norwich City    67.0
# 41                  Swansea      0.500000             Swansea City    91.0
# 42                  Cardiff      0.500000             Cardiff City    22.0
# 23                  Ipswich      0.500000             Ipswich Town    49.0
# 12                    Derby      0.500000             Derby County    36.0
# 14                Tottenham      0.500000        Tottenham Hotspur    94.0
# 2                 Newcastle      0.500000         Newcastle United    64.0
# 6                 Blackburn      0.500000         Blackburn Rovers     8.0
# 7                  Coventry      0.500000            Coventry City    30.0
# 11                 Charlton      0.500000        Charlton Athletic    24.0
# 26                   Bolton      0.500000         Bolton Wanderers    10.0
# 45             Huddersfield      0.500000        Huddersfield Town    47.0
# 15                    Leeds      0.500000             Leeds United    50.0
# 17                Leicester      0.500000           Leicester City    51.0
# 18               Nottingham      0.500000        Nottingham Forest    68.0
# 21                 Bradford      0.500000            Bradford City    13.0
# 35            Sheffield Utd      0.333333         Sheffield United    82.0
# 5              Wimbledon FC      0.333333            AFC Wimbledon     0.0
# 4             Sheffield Wed      0.333333      Sheffield Wednesday    83.0
# 44                 Brighton      0.333333   Brighton & Hove Albion    15.0
# 27                West Brom      0.250000     West Bromwich Albion    98.0
#
#                    Team_Sim
# 0                   Everton
# 13                Liverpool
# 30               Portsmouth
# 25                   Fulham
# 24          Manchester City
# 1         Manchester United
# 22               Sunderland
# 20                  Watford
# 32           Crystal Palace
# 16                  Chelsea
# 34                  Reading
# 36                Hull City
# 38                  Burnley
# 10              Aston Villa
# 9                   Arsenal
# 8               Southampton
# 39                Blackpool
# 40      Queens Park Rangers
# 3             Middlesbrough
# 43              Bournemouth
# 29  Wolverhampton Wanderers
# 19                 West Ham
# 37                    Stoke
# 28               Birmingham
# 33                    Wigan
# 31                  Norwich
# 41                  Swansea
# 42                  Cardiff
# 23                  Ipswich
# 12                    Derby
# 14                Tottenham
# 2                 Newcastle
# 6                 Blackburn
# 7                  Coventry
# 11                 Charlton
# 26                   Bolton
# 45             Huddersfield
# 15                    Leeds
# 17                Leicester
# 18               Nottingham
# 21                 Bradford
# 35            Sheffield Utd
# 5              Wimbledon FC
# 4             Sheffield Wed
# 44                 Brighton
# 27                West Brom

# %%
df_games.columns
# Out:
# Index(['GameID', 'Country', 'Tournament', 'Season', 'Round', 'Home', 'Away',
#        'Score', 'Bet_Home', 'Bet_Drawn', 'Bet_Away', 'Game_Date',
#        'Game_Details', 'Home_Team_ID', 'Away_Team_ID'],
#       dtype='object')

# %%
df_games = pd.merge(left=df_games, right=df_integracao[['Team','Match_Team','TeamID']], left_on=['Home'], right_on=['Team'], how='left')
df_games[['Home', 'Home_Team_ID']] = df_games.loc[df_games.Match_Team.notnull(), ['Match_Team','TeamID']]
#np.where(df_games.Match_Team.notnull(), df_games[['Match_Team','TeamID']], df_games[['Home','Home_Team_ID']])
df_games.drop(['Match_Team','TeamID','Team'], axis = 1, inplace=True)

df_games = pd.merge(left=df_games, right=df_integracao[['Team','Match_Team','TeamID']], left_on=['Away'], right_on=['Team'], how='left')
df_games[['Away', 'Away_Team_ID']] = df_games.loc[df_games.Match_Team.notnull(), ['Match_Team','TeamID']]
#= np.where(df_games.Match_Team.notnull(), df_games[['Match_Team','TeamID']], df_games[['Home','Home_Team_ID']])
df_games.drop(['Match_Team','TeamID','Team'], axis = 1, inplace=True)

df_games
# Out:
#       GameID  Country      Tournament     Season      Round  \
# 0     377825  England  Premier League  1998/1999   1. Round
# 1     377826  England  Premier League  1998/1999   1. Round
# 2     377827  England  Premier League  1998/1999   1. Round
# 3     377828  England  Premier League  1998/1999   1. Round
# 4     377829  England  Premier League  1998/1999   1. Round
# 5     377830  England  Premier League  1998/1999   1. Round
# 6     377831  England  Premier League  1998/1999   1. Round
# 7     377832  England  Premier League  1998/1999   1. Round
# 8     377833  England  Premier League  1998/1999   1. Round
# 9     377834  England  Premier League  1998/1999   1. Round
# 10    377835  England  Premier League  1998/1999  10. Round
# 11    377836  England  Premier League  1998/1999  10. Round
# 12    377837  England  Premier League  1998/1999  10. Round
# 13    377838  England  Premier League  1998/1999  10. Round
# 14    377839  England  Premier League  1998/1999  10. Round
# 15    377840  England  Premier League  1998/1999  10. Round
# 16    377841  England  Premier League  1998/1999  10. Round
# 17    377842  England  Premier League  1998/1999  10. Round
# 18    377843  England  Premier League  1998/1999  10. Round
# 19    377844  England  Premier League  1998/1999  10. Round
# 20    377845  England  Premier League  1998/1999  11. Round
# 21    377846  England  Premier League  1998/1999  11. Round
# 22    377847  England  Premier League  1998/1999  11. Round
# 23    377848  England  Premier League  1998/1999  11. Round
# 24    377849  England  Premier League  1998/1999  11. Round
# 25    377850  England  Premier League  1998/1999  11. Round
# 26    377851  England  Premier League  1998/1999  11. Round
# 27    377852  England  Premier League  1998/1999  11. Round
# 28    377853  England  Premier League  1998/1999  11. Round
# 29    377854  England  Premier League  1998/1999  11. Round
# ...      ...      ...             ...        ...        ...
# 7528  385353  England  Premier League  2017/2018   7. Round
# 7529  385354  England  Premier League  2017/2018   7. Round
# 7530  385355  England  Premier League  2017/2018   7. Round
# 7531  385356  England  Premier League  2017/2018   7. Round
# 7532  385357  England  Premier League  2017/2018   7. Round
# 7533  385358  England  Premier League  2017/2018   7. Round
# 7534  385359  England  Premier League  2017/2018   7. Round
# 7535  385360  England  Premier League  2017/2018   7. Round
# 7536  385361  England  Premier League  2017/2018   7. Round
# 7537  385362  England  Premier League  2017/2018   7. Round
# 7538  385363  England  Premier League  2017/2018   8. Round
# 7539  385364  England  Premier League  2017/2018   8. Round
# 7540  385365  England  Premier League  2017/2018   8. Round
# 7541  385366  England  Premier League  2017/2018   8. Round
# 7542  385367  England  Premier League  2017/2018   8. Round
# 7543  385368  England  Premier League  2017/2018   8. Round
# 7544  385369  England  Premier League  2017/2018   8. Round
# 7545  385370  England  Premier League  2017/2018   8. Round
# 7546  385371  England  Premier League  2017/2018   8. Round
# 7547  385372  England  Premier League  2017/2018   8. Round
# 7548  385373  England  Premier League  2017/2018   9. Round
# 7549  385374  England  Premier League  2017/2018   9. Round
# 7550  385375  England  Premier League  2017/2018   9. Round
# 7551  385376  England  Premier League  2017/2018   9. Round
# 7552  385377  England  Premier League  2017/2018   9. Round
# 7553  385378  England  Premier League  2017/2018   9. Round
# 7554  385379  England  Premier League  2017/2018   9. Round
# 7555  385380  England  Premier League  2017/2018   9. Round
# 7556  385381  England  Premier League  2017/2018   9. Round
# 7557  385382  England  Premier League  2017/2018   9. Round
#
#                         Home                    Away Score Bet_Home Bet_Drawn  \
# 0                    Everton             Aston Villa   0:0     3.10      2.95
# 1          Manchester United          Leicester City   2:2     1.60      2.90
# 2           Newcastle United       Charlton Athletic   0:0     1.60      2.90
# 3              Middlesbrough            Leeds United   0:0     2.70      2.70
# 4        Sheffield Wednesday         West Ham United   0:1     2.10      2.85
# 5              AFC Wimbledon       Tottenham Hotspur   3:1     2.50      2.70
# 6           Blackburn Rovers            Derby County   0:0     1.90      3.00
# 7              Coventry City                 Chelsea   2:1     2.90      2.80
# 8                Southampton               Liverpool   1:2     3.30      2.90
# 9                    Arsenal       Nottingham Forest   2:1     1.35      4.09
# 10               Aston Villa          Leicester City   1:1     1.50      3.50
# 11         Charlton Athletic         West Ham United   4:2     2.60      2.90
# 12              Derby County       Manchester United   1:1     3.50      2.95
# 13                 Liverpool       Nottingham Forest   5:1     1.35      4.40
# 14       Sheffield Wednesday                 Everton   0:0     2.20      2.80
# 15               Southampton           Coventry City   2:1     2.40      2.95
# 16         Tottenham Hotspur        Newcastle United   2:0     2.45      2.90
# 17             AFC Wimbledon           Middlesbrough   2:2     2.45      2.95
# 18          Blackburn Rovers                 Arsenal   1:2     2.60
# 19              Leeds United                 Chelsea   0:0     2.50      3.00
# 20             Middlesbrough       Nottingham Forest   1:1     1.60      3.30
# 21         Tottenham Hotspur       Charlton Athletic   2:2     1.90      3.00
# 22                   Chelsea             Aston Villa   2:1     1.95      3.10
# 23              Derby County            Leeds United   2:2     2.29      2.90
# 24                   Everton       Manchester United   1:4     4.00      3.00
# 25          Newcastle United         West Ham United   0:3     1.75      3.20
# 26            Leicester City               Liverpool   1:0     3.00      2.95
# 27       Sheffield Wednesday             Southampton   0:0     1.80      3.20
# 28             AFC Wimbledon        Blackburn Rovers   1:1     2.20      2.95
# 29             Coventry City                 Arsenal   0:1     3.75      2.85
# ...                      ...                     ...   ...      ...       ...
# 7528                 Everton                 Burnley   0:1     1.70      3.67
# 7529                 Arsenal  Brighton & Hove Albion   2:0     1.24      6.29
# 7530        Newcastle United               Liverpool   1:1     4.75      4.02
# 7531             Bournemouth          Leicester City   0:0     2.59      3.41
# 7532                 Chelsea         Manchester City   0:1     2.66      3.42
# 7533       Huddersfield Town       Tottenham Hotspur   0:4     8.62      4.65
# 7534       Manchester United          Crystal Palace   4:0     1.19      7.03
# 7535              Stoke City             Southampton   2:1     2.87      3.29
# 7536    West Bromwich Albion                 Watford   2:2     2.16      3.26
# 7537         West Ham United            Swansea City   1:0     1.84      3.55
# 7538                 Burnley         West Ham United   1:1     2.90      3.22
# 7539          Crystal Palace                 Chelsea   2:1     7.56      4.48
# 7540               Liverpool       Manchester United   0:0     2.69      3.26
# 7541         Manchester City              Stoke City   7:2     1.13      9.38
# 7542            Swansea City       Huddersfield Town   2:0     2.03      3.26
# 7543       Tottenham Hotspur             Bournemouth   1:0     1.23      6.75
# 7544                 Watford                 Arsenal   2:1     4.94      4.06
# 7545  Brighton & Hove Albion                 Everton   1:1     3.13      3.12
# 7546             Southampton        Newcastle United   2:2     1.87      3.43
# 7547          Leicester City    West Bromwich Albion   1:1     1.97      3.36
# 7548         West Ham United  Brighton & Hove Albion   0:3     1.79      3.48
# 7549                 Chelsea                 Watford   4:2     1.36      5.16
# 7550       Huddersfield Town       Manchester United   2:1     9.24      4.69
# 7551         Manchester City                 Burnley   3:0     1.11     10.42
# 7552        Newcastle United          Crystal Palace   1:0     1.85      3.54
# 7553             Southampton    West Bromwich Albion   1:0     1.84      3.33
# 7554              Stoke City             Bournemouth   1:2     2.12      3.44
# 7555            Swansea City          Leicester City   1:2     2.80      3.20
# 7556                 Everton                 Arsenal   2:5     4.43      3.79
# 7557       Tottenham Hotspur               Liverpool   4:1     2.18      3.55
#
#      Bet_Away   Game_Date                                       Game_Details  \
# 0        2.29  15.08.1998  /soccer/england/premier-league-1998-1999/evert...
# 1        6.00  15.08.1998  /soccer/england/premier-league-1998-1999/manch...
# 2        6.00  15.08.1998  /soccer/england/premier-league-1998-1999/newca...
# 3        2.70  15.08.1998  /soccer/england/premier-league-1998-1999/middl...
# 4        3.50  15.08.1998  /soccer/england/premier-league-1998-1999/sheff...
# 5        2.90  15.08.1998  /soccer/england/premier-league-1998-1999/wimbl...
# 6        4.09  15.08.1998  /soccer/england/premier-league-1998-1999/black...
# 7        2.50  15.08.1998  /soccer/england/premier-league-1998-1999/coven...
# 8        2.29  16.08.1998  /soccer/england/premier-league-1998-1999/south...
# 9        9.00  17.08.1998  /soccer/england/premier-league-1998-1999/arsen...
# 10       6.00  24.10.1998  /soccer/england/premier-league-1998-1999/aston...
# 11       2.85  24.10.1998  /soccer/england/premier-league-1998-1999/charl...
# 12       2.04  24.10.1998  /soccer/england/premier-league-1998-1999/derby...
# 13       7.00  24.10.1998  /soccer/england/premier-league-1998-1999/liver...
# 14       3.35  24.10.1998  /soccer/england/premier-league-1998-1999/sheff...
# 15       3.00  24.10.1998  /soccer/england/premier-league-1998-1999/south...
# 16       2.95  24.10.1998  /soccer/england/premier-league-1998-1999/totte...
# 17       2.95  24.10.1998  /soccer/england/premier-league-1998-1999/wimbl...
# 18       2.40  25.10.1998  /soccer/england/premier-league-1998-1999/black...
# 19       2.50  25.10.1998  /soccer/england/premier-league-1998-1999/leeds...
# 20       6.00  01.11.1998  /soccer/england/premier-league-1998-1999/middl...
# 21       3.70  02.11.1998  /soccer/england/premier-league-1998-1999/totte...
# 22       4.20  09.12.1998  /soccer/england/premier-league-1998-1999/chels...
# 23       3.10  31.10.1998  /soccer/england/premier-league-1998-1999/derby...
# 24       1.95  31.10.1998  /soccer/england/premier-league-1998-1999/evert...
# 25       5.00  31.10.1998  /soccer/england/premier-league-1998-1999/newca...
# 26       2.40  31.10.1998  /soccer/england/premier-league-1998-1999/leice...
# 27       4.80  31.10.1998  /soccer/england/premier-league-1998-1999/sheff...
# 28       3.50  31.10.1998  /soccer/england/premier-league-1998-1999/wimbl...
# 29       2.15  31.10.1998  /soccer/england/premier-league-1998-1999/coven...
# ...       ...         ...                                                ...
# 7528     5.49  01.10.2017  /soccer/england/premier-league/everton-burnley...
# 7529    13.09  01.10.2017  /soccer/england/premier-league/arsenal-brighto...
# 7530     1.71  01.10.2017  /soccer/england/premier-league/newcastle-liver...
# 7531     2.75  30.09.2017  /soccer/england/premier-league/bournemouth-lei...
# 7532     2.67  30.09.2017  /soccer/england/premier-league/chelsea-manches...
# 7533     1.41  30.09.2017  /soccer/england/premier-league/huddersfield-to...
# 7534    16.38  30.09.2017  /soccer/england/premier-league/manchester-unit...
# 7535     2.56  30.09.2017  /soccer/england/premier-league/stoke-southampt...
# 7536     3.68  30.09.2017  /soccer/england/premier-league/west-brom-watfo...
# 7537     4.60  30.09.2017  /soccer/england/premier-league/west-ham-swanse...
# 7538     2.58  14.10.2017  /soccer/england/premier-league/burnley-west-ha...
# 7539     1.45  14.10.2017  /soccer/england/premier-league/crystal-palace-...
# 7540     2.74  14.10.2017  /soccer/england/premier-league/liverpool-manch...
# 7541    18.83  14.10.2017  /soccer/england/premier-league/manchester-city...
# 7542     4.09  14.10.2017  /soccer/england/premier-league/swansea-hudders...
# 7543    12.48  14.10.2017  /soccer/england/premier-league/tottenham-bourn...
# 7544     1.68  14.10.2017  /soccer/england/premier-league/watford-arsenal...
# 7545     2.48  15.10.2017  /soccer/england/premier-league/brighton-everto...
# 7546     4.58  15.10.2017  /soccer/england/premier-league/southampton-new...
# 7547     4.21  16.10.2017  /soccer/england/premier-league/leicester-west-...
# 7548     5.10  20.10.2017  /soccer/england/premier-league/west-ham-bright...
# 7549     8.81  21.10.2017  /soccer/england/premier-league/chelsea-watford...
# 7550     1.39  21.10.2017  /soccer/england/premier-league/huddersfield-ma...
# 7551    22.30  21.10.2017  /soccer/england/premier-league/manchester-city...
# 7552     4.53  21.10.2017  /soccer/england/premier-league/newcastle-cryst...
# 7553     5.00  21.10.2017  /soccer/england/premier-league/southampton-wes...
# 7554     3.58  21.10.2017  /soccer/england/premier-league/stoke-bournemou...
# 7555     2.68  21.10.2017  /soccer/england/premier-league/swansea-leicest...
# 7556     1.81  22.10.2017  /soccer/england/premier-league/everton-arsenal...
# 7557     3.31  22.10.2017  /soccer/england/premier-league/tottenham-liver...
#
#       Home_Team_ID  Away_Team_ID
# 0             39.0           4.0
# 1             58.0          51.0
# 2             64.0          24.0
# 3             60.0          50.0
# 4             83.0          99.0
# 5              0.0          94.0
# 6              8.0          36.0
# 7             30.0          25.0
# 8             85.0          54.0
# 9              3.0          68.0
# 10             4.0          51.0
# 11            24.0          99.0
# 12            36.0          58.0
# 13            54.0          68.0
# 14            83.0          39.0
# 15            85.0          30.0
# 16            94.0          64.0
# 17             0.0          60.0
# 18             8.0           3.0
# 19            50.0          25.0
# 20            60.0          68.0
# 21            94.0          24.0
# 22            25.0           4.0
# 23            36.0          50.0
# 24            39.0          58.0
# 25            64.0          99.0
# 26            51.0          54.0
# 27            83.0          85.0
# 28             0.0           8.0
# 29            30.0           3.0
# ...            ...           ...
# 7528          39.0          18.0
# 7529           3.0          15.0
# 7530          64.0          54.0
# 7531          12.0          51.0
# 7532          25.0          57.0
# 7533          47.0          94.0
# 7534          58.0          33.0
# 7535          89.0          85.0
# 7536          98.0          97.0
# 7537          99.0          91.0
# 7538          18.0          99.0
# 7539          33.0          25.0
# 7540          54.0          58.0
# 7541          57.0          89.0
# 7542          91.0          47.0
# 7543          94.0          12.0
# 7544          97.0           3.0
# 7545          15.0          39.0
# 7546          85.0          64.0
# 7547          51.0          98.0
# 7548          99.0          15.0
# 7549          25.0          97.0
# 7550          47.0          58.0
# 7551          57.0          18.0
# 7552          64.0          33.0
# 7553          85.0          98.0
# 7554          89.0          12.0
# 7555          91.0          51.0
# 7556          39.0           3.0
# 7557          94.0          54.0
#
# [7558 rows x 15 columns]

# %%
df_games[['Home_Goals','Away_Goals']] = pd.DataFrame(df_games.Score.str.split(':',1).tolist(), columns = ['Home_Goals','Away_Goals'])
df_games.drop('Score', axis=1, inplace=True)

# %%
df_integracao
# Out:
#                        Team  Similaridade               Match_Team  TeamID  \
# 0                   Everton      1.000000                  Everton    39.0
# 13                Liverpool      1.000000                Liverpool    54.0
# 30               Portsmouth      1.000000               Portsmouth    75.0
# 25                   Fulham      1.000000                   Fulham    42.0
# 24          Manchester City      1.000000          Manchester City    57.0
# 1         Manchester United      1.000000        Manchester United    58.0
# 22               Sunderland      1.000000               Sunderland    90.0
# 20                  Watford      1.000000                  Watford    97.0
# 32           Crystal Palace      1.000000           Crystal Palace    33.0
# 16                  Chelsea      1.000000                  Chelsea    25.0
# 34                  Reading      1.000000                  Reading    78.0
# 36                Hull City      1.000000                Hull City    48.0
# 38                  Burnley      1.000000                  Burnley    18.0
# 10              Aston Villa      1.000000              Aston Villa     4.0
# 9                   Arsenal      1.000000                  Arsenal     3.0
# 8               Southampton      1.000000              Southampton    85.0
# 39                Blackpool      1.000000                Blackpool     9.0
# 40      Queens Park Rangers      1.000000      Queens Park Rangers    77.0
# 3             Middlesbrough      1.000000            Middlesbrough    60.0
# 43              Bournemouth      1.000000              Bournemouth    12.0
# 29  Wolverhampton Wanderers      1.000000  Wolverhampton Wanderers   101.0
# 19                 West Ham      0.666667          West Ham United    99.0
# 37                    Stoke      0.500000               Stoke City    89.0
# 28               Birmingham      0.500000          Birmingham City     7.0
# 33                    Wigan      0.500000           Wigan Athletic   100.0
# 31                  Norwich      0.500000             Norwich City    67.0
# 41                  Swansea      0.500000             Swansea City    91.0
# 42                  Cardiff      0.500000             Cardiff City    22.0
# 23                  Ipswich      0.500000             Ipswich Town    49.0
# 12                    Derby      0.500000             Derby County    36.0
# 14                Tottenham      0.500000        Tottenham Hotspur    94.0
# 2                 Newcastle      0.500000         Newcastle United    64.0
# 6                 Blackburn      0.500000         Blackburn Rovers     8.0
# 7                  Coventry      0.500000            Coventry City    30.0
# 11                 Charlton      0.500000        Charlton Athletic    24.0
# 26                   Bolton      0.500000         Bolton Wanderers    10.0
# 45             Huddersfield      0.500000        Huddersfield Town    47.0
# 15                    Leeds      0.500000             Leeds United    50.0
# 17                Leicester      0.500000           Leicester City    51.0
# 18               Nottingham      0.500000        Nottingham Forest    68.0
# 21                 Bradford      0.500000            Bradford City    13.0
# 35            Sheffield Utd      0.333333         Sheffield United    82.0
# 5              Wimbledon FC      0.333333            AFC Wimbledon     0.0
# 4             Sheffield Wed      0.333333      Sheffield Wednesday    83.0
# 44                 Brighton      0.333333   Brighton & Hove Albion    15.0
# 27                West Brom      0.250000     West Bromwich Albion    98.0
#
#                    Team_Sim
# 0                   Everton
# 13                Liverpool
# 30               Portsmouth
# 25                   Fulham
# 24          Manchester City
# 1         Manchester United
# 22               Sunderland
# 20                  Watford
# 32           Crystal Palace
# 16                  Chelsea
# 34                  Reading
# 36                Hull City
# 38                  Burnley
# 10              Aston Villa
# 9                   Arsenal
# 8               Southampton
# 39                Blackpool
# 40      Queens Park Rangers
# 3             Middlesbrough
# 43              Bournemouth
# 29  Wolverhampton Wanderers
# 19                 West Ham
# 37                    Stoke
# 28               Birmingham
# 33                    Wigan
# 31                  Norwich
# 41                  Swansea
# 42                  Cardiff
# 23                  Ipswich
# 12                    Derby
# 14                Tottenham
# 2                 Newcastle
# 6                 Blackburn
# 7                  Coventry
# 11                 Charlton
# 26                   Bolton
# 45             Huddersfield
# 15                    Leeds
# 17                Leicester
# 18               Nottingham
# 21                 Bradford
# 35            Sheffield Utd
# 5              Wimbledon FC
# 4             Sheffield Wed
# 44                 Brighton
# 27                West Brom

# %%
df_fifa_premier = pd.merge(left=df_fifa_england, right=df_integracao[['Match_Team','TeamID']], left_on= ['Teams'], right_on=['Match_Team'])
df_fifa_premier.drop(['Match_Team'], axis=1, inplace=True)

# %%
df_fifa_premier.to_csv('data/FIFA_Premier_League_Teams.csv', index=False)

# %%
df_games.to_csv('data/BET_Premier_League_Games.csv', index=False)
